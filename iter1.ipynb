# %%
from nba_api.stats.static import teams
nba_teams = teams.get_teams()
celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

# %%
from nba_api.stats.endpoints import leaguegamefinder
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=celtics_id)
games = gamefinder.get_data_frames()[0]
games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 0     22019  1610612738               BOS  Boston Celtics  0021900960
# 1     22019  1610612738               BOS  Boston Celtics  0021900949
# 2     22019  1610612738               BOS  Boston Celtics  0021900933
# 3     22019  1610612738               BOS  Boston Celtics  0021900917
# 4     22019  1610612738               BOS  Boston Celtics  0021900910
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2020-03-10    BOS @ IND  W  240  114  ...   0.864    11    35   46   19
# 1  2020-03-08  BOS vs. OKC  L  241  104  ...   0.789    11    35   46   22
# 2  2020-03-06  BOS vs. UTA  L  240   94  ...   0.778    13    32   45   19
# 3  2020-03-04    BOS @ CLE  W  239  112  ...   0.808    13    36   49   16
# 4  2020-03-03  BOS vs. BKN  L  266  120  ...   0.739    13    29   42   24
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    9    4    8  15         4.4
# 1    9    5   13  25        -1.0
# 2    6    6   12  13        -5.0
# 3   10    7   11  20         6.0
# 4   10    6   15  30        -9.0
#
# [5 rows x 28 columns]

# %%
games.groupby(games.SEASON_ID.str[-4:])[['GAME_ID']].count().loc['2015':]
# Out:
#            GAME_ID
# SEASON_ID
# 2015           103
# 2016           115
# 2017           113
# 2018           101
# 2019            74

# %%
# Subset the games to when the last 4 digits of SEASON_ID were 2017.
games_1718 = games[games.SEASON_ID.str[-4:] == '2017']
games_1718.head()
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 175     42017  1610612738               BOS  Boston Celtics  0041700307
# 176     42017  1610612738               BOS  Boston Celtics  0041700306
# 177     42017  1610612738               BOS  Boston Celtics  0041700305
# 178     42017  1610612738               BOS  Boston Celtics  0041700304
# 179     42017  1610612738               BOS  Boston Celtics  0041700303
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 175  2018-05-27  BOS vs. CLE  L  240   79  ...   0.737    11    31   42   18
# 176  2018-05-25    BOS @ CLE  L  241   99  ...   0.550     5    26   31   25
# 177  2018-05-23  BOS vs. CLE  W  240   96  ...   0.913     7    38   45   18
# 178  2018-05-21    BOS @ CLE  L  239  102  ...   0.767     9    28   37   21
# 179  2018-05-19    BOS @ CLE  L  240   86  ...   0.786     6    28   34   16
#
#      STL  BLK  TOV  PF  PLUS_MINUS
# 175    6    0    5  20        -8.0
# 176    5    2   13  18       -10.0
# 177   10    6    8  19        13.0
# 178    9    3    9  26        -9.0
# 179    4    4   15  25       -30.0
#
# [5 rows x 28 columns]

# %%
# Subset the games to where MATCHUP contains 'TOR'.
raps_games_1718 = games_1718[games_1718.MATCHUP.str.contains('TOR')]
raps_games_1718.head()
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION       TEAM_NAME     GAME_ID  \
# 198     22017  1610612738               BOS  Boston Celtics  0021701171
# 200     22017  1610612738               BOS  Boston Celtics  0021701140
# 221     22017  1610612738               BOS  Boston Celtics  0021700798
# 262     22017  1610612738               BOS  Boston Celtics  0021700188
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 198  2018-04-04    BOS @ TOR  L  237   78  ...   0.893     8    35   43   10
# 200  2018-03-31  BOS vs. TOR  W  240  110  ...   0.852     8    33   41   19
# 221  2018-02-06    BOS @ TOR  L  240   91  ...   0.750     9    29   38   21
# 262  2017-11-12  BOS vs. TOR  W  239   95  ...   0.789    15    31   46   24
#
#      STL  BLK  TOV  PF  PLUS_MINUS
# 198    7    3   16  16       -18.0
# 200    6    3    5  23        11.0
# 221    3    3   17  19       -20.0
# 262    9    2   14  18         1.0
#
# [4 rows x 28 columns]

# %%
last_raps_game = raps_games_1718.sort_values('GAME_DATE').iloc[-1]
last_raps_game
# Out:
# SEASON_ID                     22017
# TEAM_ID                  1610612738
# TEAM_ABBREVIATION               BOS
# TEAM_NAME            Boston Celtics
# GAME_ID                  0021701171
# GAME_DATE                2018-04-04
# MATCHUP                   BOS @ TOR
# WL                                L
# MIN                             237
# PTS                              78
# FGM                              25
# FGA                              75
# FG_PCT                        0.333
# FG3M                              3
# FG3A                             22
# FG3_PCT                       0.136
# FTM                              25
# FTA                              28
# FT_PCT                        0.893
# OREB                              8
# DREB                             35
# REB                              43
# AST                              10
# STL                               7
# BLK                               3
# TOV                              16
# PF                               16
# PLUS_MINUS                      -18
# Name: 198, dtype: object

# %%
game_id = last_raps_game.GAME_ID
game_id
# Out:
# '0021701171'

# %%
# Get **all** the games so we can filter to an individual GAME_ID
result = leaguegamefinder.LeagueGameFinder()
all_games = result.get_data_frames()[0]
# Find the game_id we want
full_game = all_games[all_games.GAME_ID == game_id]
full_game
# Out:
#       SEASON_ID     TEAM_ID TEAM_ABBREVIATION        TEAM_NAME     GAME_ID  \
# 10124     22017  1610612761               TOR  Toronto Raptors  0021701171
# 10131     22017  1610612738               BOS   Boston Celtics  0021701171
#
#         GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  \
# 10124  2018-04-04  TOR vs. BOS  W  240   96  ...   0.750    12    36   48
# 10131  2018-04-04    BOS @ TOR  L  237   78  ...   0.893     8    35   43
#
#        AST  STL  BLK  TOV  PF  PLUS_MINUS
# 10124   23   10    6   10  25        18.0
# 10131   10    7    3   16  16       -18.0
#
# [2 rows x 28 columns]
